# %% [markdown]
# <font color="green">*To start working on this notebook, or any other notebook that we will use in the Moringa Data Science Course, we will need to save our own copy of it. We can do this by clicking File > Save a Copy in Drive. We will then be able to make edits to our own copy of this notebook.*</font>

# %% [markdown]
# # Data Investigation with Pandas II

# %% [markdown]
# ## 1.0 Importing our Libraries

# %%
# Importing the libraries we will need 

# Importing the pandas library
# 
import pandas as pd

# Importing the numpy library
#
import numpy as np

# %% [markdown]
# ## 1.1 Reading the Dataset from our CSV file

# %% [markdown]
# This dataset contains trips taken by thousands of kenyans to and from Nairobi during the year 2018.
#
# *   Dataset link for download or access: [Link](https://drive.google.com/a/moringaschool.com/file/d/1xe2sHapdeGo7bIaiG7UV0rjgQZ5U6OXv/view?usp=sharing)

# %%
# Let's read the data from the CSV file and create the dataframe to be used
# 
d_parser=lambda x : pd.datetime.strptime(x,'%Y-%m-%d')
#t_parser=lambda t : pd.strptime(t,%I-%p)
df = pd.read_csv('/content/bus_travels.csv' , parse_dates=['travel_date'],date_parser=d_parser)
df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
#       ride_id travel_date travel_time  ... travel_to car_type max_capacity
# 0         247  2018-05-07       07:06  ...   Nairobi      Bus           49
# 1         256  2018-05-06       11:08  ...   Nairobi  shuttle           11
# 2         275  2018-05-04       05:00  ...   Nairobi  shuttle           11
# 3         285  2018-05-04       09:10  ...   Nairobi  shuttle           11
# 4         286  2018-05-04       09:20  ...   Nairobi  shuttle           11
# ...       ...         ...         ...  ...       ...      ...          ...
# 1106    15336  2018-05-07       07:01  ...   Nairobi      Bus           49
# 1107    15337  2018-05-07       07:08  ...   Nairobi      Bus           49
# 1108    15338  2018-05-07       07:04  ...   Nairobi      Bus           49
# 1109    15339  2018-05-07       07:05  ...   Nairobi      Bus           49
# 1110    15344  2018-05-09       08:00  ...   Nairobi      Bus           49
#
# [1111 rows x 7 columns]

# %% [markdown]
# ## 1.2 Previewing our Dataset

# %%
# Let's preview the first 10 rows of our data
# 
df.head(10)
# Out:
#    ride_id travel_date travel_time travel_from travel_to car_type  max_capacity
# 0      247  2018-05-07       07:06       Kisii   Nairobi      Bus            49
# 1      256  2018-05-06       11:08       Kisii   Nairobi  shuttle            11
# 2      275  2018-05-04       05:00       Kisii   Nairobi  shuttle            11
# 3      285  2018-05-04       09:10       Kisii   Nairobi  shuttle            11
# 4      286  2018-05-04       09:20       Kisii   Nairobi  shuttle            11
# 5      287  2018-05-04       07:02       Kisii   Nairobi      Bus            49
# 6      288  2018-05-04       09:30       Kisii   Nairobi  shuttle            11
# 7      292  2018-05-04       19:03       Kisii   Nairobi      Bus            49
# 8      298  2018-05-04       09:00       Kisii   Nairobi  shuttle            11
# 9      302  2018-05-04       08:40       Kisii   Nairobi  shuttle            11

# %% [markdown]
# ## 1.3 Accessing Information about our Dataset

# %%
# Getting to know more about the dataset by accessing its information
#
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1111 entries, 0 to 1110
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ride_id       1111 non-null   int64
#  1   travel_date   1111 non-null   object
#  2   travel_time   1111 non-null   object
#  3   travel_from   1111 non-null   object
#  4   travel_to     1111 non-null   object
#  5   car_type      1111 non-null   object
#  6   max_capacity  1111 non-null   int64
# dtypes: int64(2), object(5)
# memory usage: 60.9+ KB

# %% [markdown]
# ## 1.4 Answering Questions

# %% [markdown]
# Let's answer the following questions with our dataset

# %%
# Challenge 1
# How many trips were taken on the 22/04/18?
# 
df.loc[df['travel_date']=='2018-04-22','ride_id'].count()
# Out:
# 66

# %%
# Challenge 2
# Which type of vehicle travelled on 23/04/18 from Kisii to Nairobi at 7.15am?
#
filt=(df['travel_date']=='2018-04-23') & (df['travel_time']=='07:15')
df[filt]
# Out:
#      ride_id travel_date travel_time  ... travel_to car_type max_capacity
# 497     5676  2018-04-23       07:15  ...   Nairobi  shuttle           11
#
# [1 rows x 7 columns]

# %%
# Challenge 3
# How many trips were made from Kisii to Nairobi?
# 
filt=(df['travel_from'] == 'Kisii') & (df['travel_to'] == 'Nairobi')
ddf[filt],'ride_id'].count()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-4ce309b4e43c> in <module>()
#       3 #
#       4 filt=(df['travel_from'] == 'Kisii') & (df['travel_to'] == 'Nairobi')
# ----> 5 df[df[filt],'ride_id'].count()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             casted_key = self._maybe_cast_indexer(key)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#    2900                 raise KeyError(key) from err
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(     ride_id travel_date travel_time  ... travel_to car_type max_capacity
# 0        247  2018-05-07       07:06  ...   Nairobi      Bus           49
# 1        256  2018-05-06       11:08  ...   Nairobi  shuttle           11
# 2        275  2018-05-04       05:00  ...   Nairobi  shuttle           11
# 3        285  2018-05-04       09:10  ...   Nairobi  shuttle           11
# 4        286  2018-05-04       09:20  ...   Nairobi  shuttle           11
# ..       ...         ...         ...  ...       ...      ...          ...
# 540     5767  2018-04-21       10:58  ...   Nairobi  shuttle           11
# 541     5768  2018-04-21       07:01  ...   Nairobi      Bus           49
# 542     5779  2018-04-21       07:20  ...   Nairobi  shuttle           11
# 543     5780  2018-04-21       06:00  ...   Nairobi  shuttle           11
# 544     5782  2018-04-21       05:30  ...   Nairobi  shuttle           11
#
# [545 rows x 7 columns], 'ride_id')' is an invalid key

# %%
# Challenge 4
# How many trips were made by shuttle from Nairobi?
# 
filt=(df['car_type']=='shuttle') & (df['travel_from']=='Nairobi')
df[filt].count()
# Out:
# ride_id         0
# travel_date     0
# travel_time     0
# travel_from     0
# travel_to       0
# car_type        0
# max_capacity    0
# dtype: int64

# %%
# Challenge 5
# How many trips were made by bus from Nairobi to Awendo?
# 
filt=(df['car_type']=='Bus') & (df['travel_from']=='Nairobi') & (df['travel_to']=='Awendo')
df[filt].count()
# Out:
# ride_id         0
# travel_date     0
# travel_time     0
# travel_from     0
# travel_to       0
# car_type        0
# max_capacity    0
# dtype: int64

# %%
# Challenge 6
# Which was the most travelled from destination by bus?
# 
filt=(df['car_type']=='Bus') 
df[filt].max()
# Out:
# ride_id                       15344
# travel_date     2018-05-09 00:00:00
# travel_time                   23:12
# travel_from                    Sori
# travel_to                   Nairobi
# car_type                        Bus
# max_capacity                     49
# dtype: object

# %%
# Challenge 7
# Which was the most travelled to destination?
# 
df['travel_to'].max()
# Out:
# 'Nairobi'

# %%
# Challenge 8
# Which was the most travelled destination by bus?
# 
filt=(df['car_type']=='Bus') 
df[filt].max()
# Out:
# ride_id                       15344
# travel_date     2018-05-09 00:00:00
# travel_time                   23:12
# travel_from                    Sori
# travel_to                   Nairobi
# car_type                        Bus
# max_capacity                     49
# dtype: object

# %%
# Challenge 9
# Which town did not have a departure by shuttle?
# 
filt=df['car_type']!='shuttle'
df[filt]
# Out:
#       ride_id travel_date travel_time  ... travel_to car_type max_capacity
# 0         247  2018-05-07       07:06  ...   Nairobi      Bus           49
# 5         287  2018-05-04       07:02  ...   Nairobi      Bus           49
# 7         292  2018-05-04       19:03  ...   Nairobi      Bus           49
# 10        310  2018-05-04       08:00  ...   Nairobi      Bus           49
# 12        329  2018-05-04       07:01  ...   Nairobi      Bus           49
# ...       ...         ...         ...  ...       ...      ...          ...
# 1106    15336  2018-05-07       07:01  ...   Nairobi      Bus           49
# 1107    15337  2018-05-07       07:08  ...   Nairobi      Bus           49
# 1108    15338  2018-05-07       07:04  ...   Nairobi      Bus           49
# 1109    15339  2018-05-07       07:05  ...   Nairobi      Bus           49
# 1110    15344  2018-05-09       08:00  ...   Nairobi      Bus           49
#
# [599 rows x 7 columns]

# %%
# Challenge 10
# Which were the most 5 travelled to destinations?
# 
df.groupby('travel_from')['travel_to'].count().sort_values(ascending=False).iloc[:5]
# Out:
# travel_from
# Kisii       545
# Rongo       115
# Kijauri      79
# Homa Bay     53
# Awendo       44
# Name: travel_to, dtype: int64

# %%
# Challenge 11
# Which were the least 5 travelled to destinations?
#
df.groupby('travel_from')['travel_to'].count().sort_values(ascending=True).iloc[:5]
# Out:
# travel_from
# Sori      10
# Oyugis    12
# Keroka    21
# Mbita     25
# Sirare    28
# Name: travel_to, dtype: int64

# %%
# Challenge 12
# If all shuttles travelled with full capacity, how many people travelled in shuttles from Kisii to Nairobi in the month of May?
#
(df['max_capacity']==11).sum()
# Out:
# 512

# %%
# Challenge 13
# Which date had the highest no. of trips in June?
#
filt = (df['travel_date'] >= pd.to_datetime('2018-06-01')) & (df['travel_date'] < pd.to_datetime('2018-06-30'))
df.loc[filt]
# Out:
# Empty DataFrame
# Columns: [ride_id, travel_date, travel_time, travel_from, travel_to, car_type, max_capacity]
# Index: []

# %%
# Challenge 14
# On average, how many trips were made by all vehicles in a day?
#

# %%
# Challenge 15 
# On average, how many buses and shuttles travelled in a day?
# 
filt=(df['car_type']=='Bus') & (df['car_type']=='shuttle')
df[filt]
# Out:
# Empty DataFrame
# Columns: [ride_id, travel_date, travel_time, travel_from, travel_to, car_type, max_capacity]
# Index: []
