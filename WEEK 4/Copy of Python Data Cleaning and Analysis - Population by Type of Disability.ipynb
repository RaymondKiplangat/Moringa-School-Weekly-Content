# %% [markdown]
# <font color="green">*To start working on this notebook, or any other notebook that we will use in the Moringa Data Science Course, we will need to save our own copy of it. We can do this by clicking File > Save a Copy in Drive. We will then be able to make edits to our own copy of this notebook.*</font>

# %% [markdown]
# # Python Data Cleaning and Analysis - Population by Type of Disability

# %% [markdown]
# ## 1.0 Importing our Libraries

# %%
# Importing the libraries we will need 

# Importing the pandas library
# 
import pandas as pd
# Importing the numpy library
#
import numpy as np

# %% [markdown]
# ## 1.1 Reading the Dataset from our CSV file

# %% [markdown]
# The dataset we will use contains the percentage distribution of population by type of disability for Kenyan counties.
#
#
# *   Dataset link for download or access: [Link](https://drive.google.com/a/moringaschool.com/file/d/13twDwhbJqBr1Dvmlwzv6Mou-irul77cS/view?usp=sharing)

# %%
# Let's read the data from the CSV file and create the dataframe to be used
# 
df=pd.read_csv('/content/Percentage_Distribution_of_Population_by_type_of_Disability_County_Estimates2005_6.csv')
df
# Out:
#              County Missing_Hand  ...              Location_1 OBJECTID
# 0           Baringo        10.9%  ...   (0.512912, 35.952537)        0
# 1             Bomet           0%  ...  (-0.690131, 35.278005)        1
# 2           Bungoma        12.3%  ...   (0.737046, 34.672536)        2
# 3             Busia           0%  ...   (0.428414, 34.210571)        3
# 4   Elgeyo Marakwet           0%  ...   (0.806011, 35.564093)        4
# 5              Embu           0%  ...    (-0.5982, 37.653906)        5
# 6           Garissa           0%  ...  (-0.564679, 40.408457)        6
# 7          Homa Bay         2.1%  ...  (-0.640985, 34.411083)        7
# 8            Isiolo        13.9%  ...   (0.949302, 38.614718)        8
# 9           Kajiado           0%  ...  (-2.221971, 36.980268)        9
# 10         Kakamega           1%  ...   (0.308499, 34.654844)       10
# 11          Kericho           0%  ...  (-0.297842, 35.319833)       11
# 12           Kiambu           0%  ...   (-1.060698, 36.79929)       12
# 13           Kilifi         2.5%  ...   (-3.279972, 39.63501)       13
# 14        Kirinyaga           0%  ...  (-0.517766, 37.302006)       14
# 15            Kisii           0%  ...  (-0.782524, 34.766895)       15
# 16           Kisumu         7.6%  ...  (-0.167225, 34.953647)       16
# 17            Kitui           0%  ...  (-1.519146, 38.376101)       17
# 18            Kwale           0%  ...  (-4.242667, 39.174233)       18
# 19         Laikipia           0%  ...   (0.311627, 36.814178)       19
# 20             Lamu           0%  ...   (-2.03752, 40.688214)       20
# 21         Machakos           0%  ...  (-1.327138, 37.352277)       21
# 22          Makueni           0%  ...  (-2.211917, 37.865047)       22
# 23          Mandera           0%  ...    (3.46712, 40.704671)       23
# 24         Marsabit         1.5%  ...    (2.772167, 37.76822)       24
# 25             Meru           0%  ...   (0.159398, 37.750761)       25
# 26           Migori           6%  ...   (-1.008592, 34.42681)       26
# 27          Mombasa           0%  ...  (-3.998813, 39.632129)       27
# 28         Murang'a           0%  ...  (-0.804314, 37.035566)       28
# 29          Nairobi           0%  ...  (-1.296975, 36.844534)       29
# 30           Nakuru         0.4%  ...  (-0.385212, 36.036261)       30
# 31            Nandi           0%  ...   (0.143371, 35.156125)       31
# 32            Narok         5.4%  ...  (-1.227452, 35.686784)       32
# 33          Nyamira           0%  ...  (-0.644917, 34.955612)       33
# 34        Nyandarua        21.2%  ...  (-0.374727, 36.494076)       34
# 35            Nyeri           0%  ...  (-0.407168, 36.965186)       35
# 36          Samburu        11.6%  ...   (1.183862, 37.184377)       36
# 37            Siaya           0%  ...   (0.039184, 34.279374)       37
# 38     Taita Taveta           0%  ...  (-3.551502, 38.376101)       38
# 39       Tana River           0%  ...  (-1.584971, 39.536272)       39
# 40    Tharaka Nithi           0%  ...  (-0.227324, 37.882411)       40
# 41      Trans Nzoia           0%  ...   (1.030597, 34.949297)       41
# 42          Turkana           0%  ...   (3.318344, 35.401457)       42
# 43      Uasin Gishu           0%  ...   (0.555288, 35.306307)       43
# 44           Vihiga           0%  ...     (0.0785, 34.717749)       44
# 45            Wajir         1.3%  ...    (1.895541, 40.07933)       45
# 46       West Pokot           0%  ...   (1.575837, 35.316901)       46
# 47    Kenya average         1.9%  ...                     NaN       47
#
# [48 rows x 13 columns]

# %% [markdown]
# ## 1.2 Previewing our Dataset

# %%
# Let's preview the first 10 rows of our data
df.head(10)
# Out:
#             County Missing_Hand  ...              Location_1 OBJECTID
# 0          Baringo        10.9%  ...   (0.512912, 35.952537)        0
# 1            Bomet           0%  ...  (-0.690131, 35.278005)        1
# 2          Bungoma        12.3%  ...   (0.737046, 34.672536)        2
# 3            Busia           0%  ...   (0.428414, 34.210571)        3
# 4  Elgeyo Marakwet           0%  ...   (0.806011, 35.564093)        4
# 5             Embu           0%  ...    (-0.5982, 37.653906)        5
# 6          Garissa           0%  ...  (-0.564679, 40.408457)        6
# 7         Homa Bay         2.1%  ...  (-0.640985, 34.411083)        7
# 8           Isiolo        13.9%  ...   (0.949302, 38.614718)        8
# 9          Kajiado           0%  ...  (-2.221971, 36.980268)        9
#
# [10 rows x 13 columns]

# %% [markdown]
# ## 1.3 Accessing Information about our Dataset

# %%
# Getting to know more about the dataset by accessing its information
# 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   County        48 non-null     object
#  1   Missing_Hand  48 non-null     object
#  2   Missing_Foot  48 non-null     object
#  3   Lame          48 non-null     object
#  4   Blind         48 non-null     object
#  5   Deaf          48 non-null     object
#  6   Dumb          48 non-null     object
#  7   Mental        48 non-null     object
#  8   Paralyzed     48 non-null     object
#  9   Other         48 non-null     object
#  10  Total_Count   48 non-null     float64
#  11  Location_1    47 non-null     object
#  12  OBJECTID      48 non-null     int64
# dtypes: float64(1), int64(1), object(11)
# memory usage: 5.0+ KB

# %%
#cols = ['Missing_Hand', 'Missing_Foot','Blind','Dumb','Lame','Deaf','Mental','Paralyzed','Other']
#df[cols] = df[cols].apply(pd.to_numeric, errors='coerce', axis=1)

# %%
df[cols].dtypes
# Out:
# Missing_Hand    object
# Missing_Foot    object
# Blind           object
# Dumb            object
# Lame            object
# Deaf            object
# Mental          object
# Paralyzed       object
# Other           object
# dtype: object

# %% [markdown]
# ## 1.4 Cleaning our Dataset

# %% [markdown]
# Let us perform data cleaning procedures below providing a documentation for our actions and reasons. We will perform as many data cleaning procedures as we think suitable for the various dimensions of data.

# %% [markdown]
# ### 1.41) Validity: <font color="green">Challenges</font>

# %%
# Procedure 1: Irrelevant Data Observation
# Data Cleaning Action: Dropping Location_1 attribute
# Explanation: We won't need it during Analysis. No question to be answered requires that column.
#
df.drop('Location_1',axis=1, inplace=True)
print(df)
# Out:
#              County Missing_Hand Missing_Foot  ...  Other Total_Count OBJECTID
# 0           Baringo        10.9%         2.8%  ...  10.9%      6512.1        0
# 1             Bomet           0%           0%  ...  38.7%      6538.0        1
# 2           Bungoma        12.3%           0%  ...  21.9%     13170.6        2
# 3             Busia           0%           0%  ...  31.4%      6655.5        3
# 4   Elgeyo Marakwet           0%           0%  ...   7.4%      3599.9        4
# 5              Embu           0%           0%  ...  41.8%      6287.4        5
# 6           Garissa           0%        37.1%  ...  51.6%      1864.1        6
# 7          Homa Bay         2.1%           0%  ...  48.3%     23696.8        7
# 8            Isiolo        13.9%         3.3%  ...  19.8%      2154.4        8
# 9           Kajiado           0%           0%  ...  45.5%      3250.3        9
# 10         Kakamega           1%           0%  ...  51.7%     27468.9       10
# 11          Kericho           0%           0%  ...  73.6%      3055.8       11
# 12           Kiambu           0%           0%  ...  11.6%     10099.9       12
# 13           Kilifi         2.5%           0%  ...   2.5%      6996.6       13
# 14        Kirinyaga           0%           0%  ...     0%      2522.8       14
# 15            Kisii           0%         6.6%  ...  23.8%      9627.8       15
# 16           Kisumu         7.6%           0%  ...  41.4%     20026.3       16
# 17            Kitui           0%         9.3%  ...   7.6%      4403.0       17
# 18            Kwale           0%         9.1%  ...  19.5%      8503.0       18
# 19         Laikipia           0%           0%  ...     0%      1825.7       19
# 20             Lamu           0%           0%  ...  65.3%       524.9       20
# 21         Machakos           0%           0%  ...  58.9%     23460.4       21
# 22          Makueni           0%           0%  ...  30.5%     15475.4       22
# 23          Mandera           0%         1.4%  ...  10.9%      3343.5       23
# 24         Marsabit         1.5%         9.7%  ...  18.3%      3931.5       24
# 25             Meru           0%           0%  ...  57.2%     19166.3       25
# 26           Migori           6%         6.9%  ...  30.1%     15359.3       26
# 27          Mombasa           0%           0%  ...  22.6%      5413.4       27
# 28         Murang'a           0%           0%  ...  15.5%      8512.1       28
# 29          Nairobi           0%        12.6%  ...  18.9%     14936.2       29
# 30           Nakuru         0.4%           0%  ...  15.7%     21598.0       30
# 31            Nandi           0%         9.1%  ...  49.1%     11530.7       31
# 32            Narok         5.4%         0.6%  ...  14.4%      7986.1       32
# 33          Nyamira           0%           0%  ...     0%      4727.3       33
# 34        Nyandarua        21.2%           0%  ...     0%      2369.6       34
# 35            Nyeri           0%        16.1%  ...     0%      2392.6       35
# 36          Samburu        11.6%          10%  ...     0%      2574.9       36
# 37            Siaya           0%           0%  ...  23.6%      6279.4       37
# 38     Taita Taveta           0%         3.7%  ...   5.9%      3709.8       38
# 39       Tana River           0%           0%  ...   8.1%      3699.8       39
# 40    Tharaka Nithi           0%           0%  ...  29.3%       420.1       40
# 41      Trans Nzoia           0%           0%  ...  68.2%      8251.9       41
# 42          Turkana           0%           0%  ...     0%      1733.1       42
# 43      Uasin Gishu           0%           0%  ...  58.1%      9281.6       43
# 44           Vihiga           0%           0%  ...  26.9%     23490.6       44
# 45            Wajir         1.3%         5.2%  ...     0%      9276.5       45
# 46       West Pokot           0%          14%  ...  12.6%      4874.2       46
# 47    Kenya average         1.9%         2.3%  ...  31.7%    402578.1       47
#
# [48 rows x 12 columns]

# %%
# Procedure 2: Irrelevant Data Observation
# Data Cleaning Action: Drop OBJECTID attribute
# Explanation: Its irrelevant to our table i.e. attribute starts from 0 and ends of 48 i.e. No meaning at all.
# 
df.drop('OBJECTID',axis=1, inplace=True)
print(df)
# Out:
#              County Missing_Hand Missing_Foot  ... Paralyzed  Other Total_Count
# 0           Baringo        10.9%         2.8%  ...     54.2%  10.9%      6512.1
# 1             Bomet           0%           0%  ...      0.3%  38.7%      6538.0
# 2           Bungoma        12.3%           0%  ...        0%  21.9%     13170.6
# 3             Busia           0%           0%  ...     14.8%  31.4%      6655.5
# 4   Elgeyo Marakwet           0%           0%  ...     12.6%   7.4%      3599.9
# 5              Embu           0%           0%  ...      2.5%  41.8%      6287.4
# 6           Garissa           0%        37.1%  ...     11.3%  51.6%      1864.1
# 7          Homa Bay         2.1%           0%  ...        9%  48.3%     23696.8
# 8            Isiolo        13.9%         3.3%  ...        2%  19.8%      2154.4
# 9           Kajiado           0%           0%  ...        0%  45.5%      3250.3
# 10         Kakamega           1%           0%  ...      6.3%  51.7%     27468.9
# 11          Kericho           0%           0%  ...     21.7%  73.6%      3055.8
# 12           Kiambu           0%           0%  ...      7.6%  11.6%     10099.9
# 13           Kilifi         2.5%           0%  ...      9.9%   2.5%      6996.6
# 14        Kirinyaga           0%           0%  ...     33.6%     0%      2522.8
# 15            Kisii           0%         6.6%  ...       11%  23.8%      9627.8
# 16           Kisumu         7.6%           0%  ...        3%  41.4%     20026.3
# 17            Kitui           0%         9.3%  ...     19.4%   7.6%      4403.0
# 18            Kwale           0%         9.1%  ...      6.4%  19.5%      8503.0
# 19         Laikipia           0%           0%  ...        0%     0%      1825.7
# 20             Lamu           0%           0%  ...      2.9%  65.3%       524.9
# 21         Machakos           0%           0%  ...       18%  58.9%     23460.4
# 22          Makueni           0%           0%  ...     10.9%  30.5%     15475.4
# 23          Mandera           0%         1.4%  ...      9.2%  10.9%      3343.5
# 24         Marsabit         1.5%         9.7%  ...     23.9%  18.3%      3931.5
# 25             Meru           0%           0%  ...        4%  57.2%     19166.3
# 26           Migori           6%         6.9%  ...     15.4%  30.1%     15359.3
# 27          Mombasa           0%           0%  ...     25.8%  22.6%      5413.4
# 28         Murang'a           0%           0%  ...     10.1%  15.5%      8512.1
# 29          Nairobi           0%        12.6%  ...      1.1%  18.9%     14936.2
# 30           Nakuru         0.4%           0%  ...     12.7%  15.7%     21598.0
# 31            Nandi           0%         9.1%  ...        0%  49.1%     11530.7
# 32            Narok         5.4%         0.6%  ...     32.5%  14.4%      7986.1
# 33          Nyamira           0%           0%  ...        0%     0%      4727.3
# 34        Nyandarua        21.2%           0%  ...        0%     0%      2369.6
# 35            Nyeri           0%        16.1%  ...        0%     0%      2392.6
# 36          Samburu        11.6%          10%  ...        0%     0%      2574.9
# 37            Siaya           0%           0%  ...       10%  23.6%      6279.4
# 38     Taita Taveta           0%         3.7%  ...     20.4%   5.9%      3709.8
# 39       Tana River           0%           0%  ...      9.2%   8.1%      3699.8
# 40    Tharaka Nithi           0%           0%  ...        0%  29.3%       420.1
# 41      Trans Nzoia           0%           0%  ...        0%  68.2%      8251.9
# 42          Turkana           0%           0%  ...     92.2%     0%      1733.1
# 43      Uasin Gishu           0%           0%  ...      7.2%  58.1%      9281.6
# 44           Vihiga           0%           0%  ...        0%  26.9%     23490.6
# 45            Wajir         1.3%         5.2%  ...     15.8%     0%      9276.5
# 46       West Pokot           0%          14%  ...     30.9%  12.6%      4874.2
# 47    Kenya average         1.9%         2.3%  ...       10%  31.7%    402578.1
#
# [48 rows x 11 columns]

# %%
# Procedure 3:
# Data Cleaning Action:
# Explanation:
#
df.isnull().sum()
# Out:
# County          0
# Missing_Hand    0
# Missing_Foot    0
# Lame            0
# Blind           0
# Deaf            0
# Dumb            0
# Mental          0
# Paralyzed       0
# Other           0
# Total_Count     0
# dtype: int64

# %%
# Procedure 4:
# Data Cleaning Action:
# Explanation:
#

# %% [markdown]
# ### 1.42) Accuracy <font color="green">Challenges</font>

# %%
# Procedure 1:
# Data Cleaning Action:
# Explanation:
#
#df.replace(to_replace = '%', value = '', inplace = True)
#df

# %% [markdown]
# ### 1.43) Completeness <font color="green">Challenges</font>

# %%
# Procedure 1:
# Data Cleaning Action:
# Explanation:
#
df.isnull().sum()
# Out:
# County          0
# Missing_Hand    0
# Missing_Foot    0
# Lame            0
# Blind           0
# Deaf            0
# Dumb            0
# Mental          0
# Paralyzed       0
# Other           0
# Total_Count     0
# dtype: int64

# %%
# Procedure 2:
# Data Cleaning Action:
# Explanation:
#

# %% [markdown]
# ### 1.44) Consitency: <font color="green">Challenges</font>

# %%
# Procedure 1: Duplicates
# Data Cleaning Action: No action taken
# Explanation: There were no duplicate instances
#
df_non_duplicates = df.drop_duplicates()
print(df_non_duplicates)

#There were no duplicates.
# Out:
#              County Missing_Hand Missing_Foot  ... Paralyzed  Other Total_Count
# 0           Baringo        10.9%         2.8%  ...     54.2%  10.9%      6512.1
# 1             Bomet           0%           0%  ...      0.3%  38.7%      6538.0
# 2           Bungoma        12.3%           0%  ...        0%  21.9%     13170.6
# 3             Busia           0%           0%  ...     14.8%  31.4%      6655.5
# 4   Elgeyo Marakwet           0%           0%  ...     12.6%   7.4%      3599.9
# 5              Embu           0%           0%  ...      2.5%  41.8%      6287.4
# 6           Garissa           0%        37.1%  ...     11.3%  51.6%      1864.1
# 7          Homa Bay         2.1%           0%  ...        9%  48.3%     23696.8
# 8            Isiolo        13.9%         3.3%  ...        2%  19.8%      2154.4
# 9           Kajiado           0%           0%  ...        0%  45.5%      3250.3
# 10         Kakamega           1%           0%  ...      6.3%  51.7%     27468.9
# 11          Kericho           0%           0%  ...     21.7%  73.6%      3055.8
# 12           Kiambu           0%           0%  ...      7.6%  11.6%     10099.9
# 13           Kilifi         2.5%           0%  ...      9.9%   2.5%      6996.6
# 14        Kirinyaga           0%           0%  ...     33.6%     0%      2522.8
# 15            Kisii           0%         6.6%  ...       11%  23.8%      9627.8
# 16           Kisumu         7.6%           0%  ...        3%  41.4%     20026.3
# 17            Kitui           0%         9.3%  ...     19.4%   7.6%      4403.0
# 18            Kwale           0%         9.1%  ...      6.4%  19.5%      8503.0
# 19         Laikipia           0%           0%  ...        0%     0%      1825.7
# 20             Lamu           0%           0%  ...      2.9%  65.3%       524.9
# 21         Machakos           0%           0%  ...       18%  58.9%     23460.4
# 22          Makueni           0%           0%  ...     10.9%  30.5%     15475.4
# 23          Mandera           0%         1.4%  ...      9.2%  10.9%      3343.5
# 24         Marsabit         1.5%         9.7%  ...     23.9%  18.3%      3931.5
# 25             Meru           0%           0%  ...        4%  57.2%     19166.3
# 26           Migori           6%         6.9%  ...     15.4%  30.1%     15359.3
# 27          Mombasa           0%           0%  ...     25.8%  22.6%      5413.4
# 28         Murang'a           0%           0%  ...     10.1%  15.5%      8512.1
# 29          Nairobi           0%        12.6%  ...      1.1%  18.9%     14936.2
# 30           Nakuru         0.4%           0%  ...     12.7%  15.7%     21598.0
# 31            Nandi           0%         9.1%  ...        0%  49.1%     11530.7
# 32            Narok         5.4%         0.6%  ...     32.5%  14.4%      7986.1
# 33          Nyamira           0%           0%  ...        0%     0%      4727.3
# 34        Nyandarua        21.2%           0%  ...        0%     0%      2369.6
# 35            Nyeri           0%        16.1%  ...        0%     0%      2392.6
# 36          Samburu        11.6%          10%  ...        0%     0%      2574.9
# 37            Siaya           0%           0%  ...       10%  23.6%      6279.4
# 38     Taita Taveta           0%         3.7%  ...     20.4%   5.9%      3709.8
# 39       Tana River           0%           0%  ...      9.2%   8.1%      3699.8
# 40    Tharaka Nithi           0%           0%  ...        0%  29.3%       420.1
# 41      Trans Nzoia           0%           0%  ...        0%  68.2%      8251.9
# 42          Turkana           0%           0%  ...     92.2%     0%      1733.1
# 43      Uasin Gishu           0%           0%  ...      7.2%  58.1%      9281.6
# 44           Vihiga           0%           0%  ...        0%  26.9%     23490.6
# 45            Wajir         1.3%         5.2%  ...     15.8%     0%      9276.5
# 46       West Pokot           0%          14%  ...     30.9%  12.6%      4874.2
# 47    Kenya average         1.9%         2.3%  ...       10%  31.7%    402578.1
#
# [48 rows x 11 columns]

# %% [markdown]
# ### 1.45) Uniformity: <font color="green">Challenges<font/>

# %%
# Procedure 1: 
# Data Cleaning Action:
# Explanation:
#

# %%
# Procedure 2:
# Data Cleaning Action:
# Explanation:
#

# %% [markdown]
# ### Exporting the Cleaned Dataset

# %%
# Let's export our dataframe into a csv file as shown 
# in the example given in the following line;
# daframe.to_csv('example.csv')
# In the above case daframe is the dataframe which would like to export.
# we use the to_csv function to create a csv file with the name example 
# and export it
#

# %% [markdown]
# ## 1.5 Answering Questions

# %% [markdown]
# Let's answer the following questions with our dataset using python.

# %%
# Challenge 1
# Which county had the highest no. of registered deaf persons?
# 
df[df['County'],'Deaf'].max()

# %%
# Challenge 2
# Which county had the highest no. of registered persons with a missing hand?
#
df[df['County'],'Missing_Hand'].max()

# %%
# Challenge 3
# Which county had the highest no. of registered persons with a missing foot?
# 
df[df['County'],'Missing_Foot'].max()

# %%
# Challenge 4
# Which county had the highest no. of registered lame persons?
# 
df[df['County'],'lame'].max()

# %%
# Challenge 5
# Which county had the lowest no. of registered blind persons?
# 
df[df['County'],'Blind'].min()

# %%
# Challenge 6
# Which county had the highest third no. of registered deaf persons?
# 
df.groupby('County')['Deaf'].max().sort_values

# %%
# Challenge 7
# In descending order, which top 5 counties had the highest no. of registered dumb persons?
# 
df.groupby('County')['Dumb'].max()

# %%
# Challenge 8
# In ascending order, which top 5 counties had the highest no. of registered persons with a mental disability? 
# 
OUR CODE GOES HERE

# %%
# Challenge 9
# Which counties had no registerd blind persons nor deaf persons?
# 
OUR CODE GOES HERE

# %%
# Challenge 10
# Which disability was the most registered across all the counties?
# 
OUR CODE GOES HERE

# %%
# Challenge 11
# Which disability was the least registered across all the counties?
#
OUR CODE GOES HERE

# %%
# Challenge 12
# What was the average no. of registered persons with a disability?
#
OUR CODE GOES HERE

# %%
# Challenge 13
# Which three counties had least registered persons with disabilities?
#
OUR CODE GOES HERE

# %%
# Challenge 14
# What was the total no of registered persons with a disability across all counties?
#
OUR CODE GOES HERE

# %%
# Challenge 15 
# Which top 3 counties has the highest no. of registered persons with a disability?
# 
OUR CODE GOES HERE
