# %% [markdown]
# <font color="green">*To start working on this notebook, or any other notebook that we will use in the Moringa Data Science Course, we will need to save our own copy of it. We can do this by clicking File > Save a Copy in Drive. We will then be able to make edits to our own copy of this notebook.*</font>

# %% [markdown]
# # SQL Programming - Subqueries using Select Statements

# %% [markdown]
# ## 1.0 Connecting to our Database

# %%
# We will first load the sql extension into our environment
# %load_ext sql

# Then connect to our in memory sqlite database
# NB: This database will cease to exist as soon as the database connection is closed. 
# %sql sqlite://
# Out:
# 'Connected: @None'

# %% [markdown]
# ## 1.1 Loading Data from CSV Files

# %% [markdown]
# Datasets used in this notebook:
#
#
# 1.   **World Countries**
#
# > ([Dataset Download Link](https://drive.google.com/a/moringaschool.com/file/d/1XlabneVWhvbmpRUi_Wix2FR5uYAAp-ZY/view?usp=sharing))
#
# 2.   **World Cities**
#
# > ([Dataset Download Link](https://drive.google.com/a/moringaschool.com/file/d/1R5952m-8hH91uiwDK8dcL9sT2D_PEcuw/view?usp=sharing))

# %%
# Importing Pandas
import pandas as pd

# %%
# Loading our Countries dataset
# 
# Loading our table from the respective CSV files 
with open('/content/world_countries.csv','r') as f:
    world_countries = pd.read_csv(f, index_col=0, encoding='utf-8')
# saving the urban center CSV file into a database
#%sql DROP TABLE if EXISTS Urban_Centres;
# %sql PERSIST world_countries;

# Displaying the first  5 entries 
# %sql SELECT * FROM world_countries;
# Out:
#  * sqlite://
#  * sqlite://
# Done.
# [('Albania', 2.9, 'no', 'yes'),
#  ('Andorra', 0.07, 'no', 'no'),
#  ('Austria', 8.57, 'yes', 'no'),
#  ('Belarus', 9.48, 'no', 'no'),
#  ('Belgium', 11.37, 'yes', 'yes'),
#  ('Bosnia and Herzegovina', 3.8, 'no', 'yes'),
#  ('Bulgaria', 7.1, 'yes', 'yes'),
#  ('Croatia', 4.23, 'yes', 'yes'),
#  ('Cyprus', 1.18, 'yes', 'yes'),
#  ('Czech Republic', 10.55, 'yes', 'no'),
#  ('Denmark', 5.69, 'yes', 'yes'),
#  ('Estonia', 1.31, 'yes', 'yes'),
#  ('Finland', 5.52, 'yes', 'yes'),
#  ('France', 64.67, 'yes', 'yes'),
#  ('Germany', 80.68, 'yes', 'yes'),
#  ('Greece', 10.92, 'yes', 'yes'),
#  ('Hungary', 9.82, 'yes', 'no'),
#  ('Iceland', 0.33, 'no', 'yes'),
#  ('Ireland', 4.71, 'yes', 'yes'),
#  ('Italy', 59.8, 'yes', 'yes'),
#  ('Kosovo', 1.91, 'no', 'no'),
#  ('Latvia', 1.96, 'yes', 'yes'),
#  ('Liechtenstein', 0.04, 'no', 'no'),
#  ('Lithuania', 2.85, 'yes', 'yes'),
#  ('Luxembourg', 0.58, 'yes', 'no'),
#  ('Macedonia', 2.08, 'no', 'no'),
#  ('Moldova', 4.06, 'no', 'no'),
#  ('Montenegro', 0.63, 'no', 'yes'),
#  ('Netherlands', 16.98, 'yes', 'yes'),
#  ('Norway', 5.27, 'no', 'yes'),
#  ('Poland', 38.59, 'yes', 'yes'),
#  ('Portugal', 10.3, 'yes', 'yes'),
#  ('Romania', 19.37, 'yes', 'yes'),
#  ('Serbia', 8.81, 'no', 'no'),
#  ('Slovakia', 5.43, 'yes', 'no'),
#  ('Slovenia', 2.07, 'yes', 'yes'),
#  ('Spain', 46.06, 'yes', 'yes'),
#  ('Sweden', 9.85, 'yes', 'yes'),
#  ('Switzerland', 8.38, 'no', 'no'),
#  ('Turkey', 79.62, 'no', 'yes'),
#  ('Ukraine', 44.62, 'no', 'yes'),
#  ('United Kingdom', 65.11, 'yes', 'yes')]

# %%
# Loading our cities dataset
# 
# Loading our table from the respective CSV files 
with open('/content/world_cities.csv','r') as f:
    world_cities = pd.read_csv(f, index_col=0, encoding='utf-8')
# saving the urban center CSV file into a database
#%sql DROP TABLE if EXISTS Urban_Centres;
# %sql PERSIST world_cities;

# Displaying the first  5 entries 
# %sql SELECT * FROM world_cities ;
# Out:
#  * sqlite://
#  * sqlite://
# Done.
# [('Aalborg', 'Denmark', 57.03, 9.92, 7.52),
#  ('Aberdeen', 'United Kingdom', 57.17, -2.08, 8.1),
#  ('Abisko', 'Sweden', 63.35, 18.83, 0.2),
#  ('Adana', 'Turkey', 36.99, 35.32, 18.67),
#  ('Albacete', 'Spain', 39.0, -1.87, 12.62),
#  ('Algeciras', 'Spain', 36.13, -5.47, 17.38),
#  ('Amiens', 'France', 49.9, 2.3, 10.17),
#  ('Amsterdam', 'Netherlands', 52.35, 4.92, 8.93),
#  ('Ancona', 'Italy', 43.6, 13.5, 13.52),
#  ('Andorra', 'Andorra', 42.5, 1.52, 9.6),
#  ('Angers', 'France', 47.48, -0.53, 10.98),
#  ('Ankara', 'Turkey', 39.93, 32.86, 9.86),
#  ('Antalya', 'Turkey', 36.89, 30.7, 11.88),
#  ('Arad', 'Romania', 46.17, 21.32, 9.32),
#  ('Athens', 'Greece', 37.98, 23.73, 17.41),
#  ('Augsburg', 'Germany', 48.35, 10.9, 4.54),
#  ('Bacau', 'Romania', 46.58, 26.92, 7.51),
#  ('Badajoz', 'Spain', 38.88, -6.97, 15.61),
#  ('Baia Mare', 'Romania', 47.66, 23.58, 8.87),
#  ('Balti', 'Moldova', 47.76, 27.91, 8.23),
#  ('Barcelona', 'Spain', 41.38, 2.18, 15.78),
#  ('Bari', 'Italy', 41.11, 16.87, 15.15),
#  ('Basel', 'Switzerland', 47.58, 7.59, 6.68),
#  ('Batman', 'Turkey', 37.89, 41.14, 14.16),
#  ('Belfast', 'United Kingdom', 54.6, -5.96, 8.48),
#  ('Belgrade', 'Serbia', 44.82, 20.47, 9.85),
#  ('Bergamo', 'Italy', 45.7, 9.67, 9.12),
#  ('Bergen', 'Norway', 60.39, 5.32, 1.75),
#  ('Berlin', 'Germany', 52.52, 13.4, 8.72),
#  ('Bialystok', 'Poland', 53.15, 23.17, 6.07),
#  ('Bielefeld', 'Germany', 52.03, 8.53, 8.78),
#  ('Bila Tserkva', 'Ukraine', 49.77, 30.13, 6.98),
#  ('Bilbao', 'Spain', 43.25, -2.93, 11.41),
#  ('Birmingham', 'United Kingdom', 52.47, -1.92, 8.81),
#  ('Blackpool', 'United Kingdom', 53.83, -3.05, 9.15),
#  ('Bodo', 'Norway', 67.25, 14.4, 4.5),
#  ('Bologna', 'Italy', 44.5, 11.34, 11.69),
#  ('Bonn', 'Germany', 50.72, 7.08, 8.63),
#  ('Bordeaux', 'France', 44.85, -0.6, 11.87),
#  ('Botosani', 'Romania', 47.75, 26.66, 8.23),
#  ('Bournemouth', 'United Kingdom', 50.73, -1.9, 9.97),
#  ('Bradford', 'United Kingdom', 53.8, -1.75, 8.39),
#  ('Braga', 'Portugal', 41.55, -8.42, 13.42),
#  ('Braila', 'Romania', 45.29, 27.97, 9.78),
#  ('Bratislava', 'Slovakia', 48.15, 17.12, 9.65),
#  ('Bremen', 'Germany', 53.08, 8.8, 8.14),
#  ('Brest', 'France', 48.39, -4.5, 11.02),
#  ('Brest', 'Belarus', 52.1, 23.7, 6.73),
#  ('Brno', 'Czech Republic', 49.2, 16.61, 7.86),
#  ('Brugge', 'Belgium', 51.22, 3.23, 9.65),
#  ('Bucharest', 'Romania', 44.43, 26.1, 10.59),
#  ('Budapest', 'Hungary', 47.5, 19.08, 9.55),
#  ('Burgas', 'Bulgaria', 42.51, 27.47, 11.93),
#  ('Burgos', 'Spain', 42.35, -3.68, 10.45),
#  ('Bursa', 'Turkey', 40.2, 29.07, 11.16),
#  ('Bydgoszcz', 'Poland', 53.12, 18.01, 7.14),
#  ('Bytom', 'Poland', 50.35, 18.91, 7.66),
#  ('Caen', 'France', 49.18, -0.35, 9.96),
#  ('Cambridge', 'United Kingdom', 52.2, 0.12, 9.25),
#  ('Cartagena', 'Spain', 37.6, -0.98, 17.32),
#  ('Catania', 'Italy', 37.5, 15.08, 15.04),
#  ('Chemnitz', 'Germany', 50.83, 12.92, 8.05),
#  ('Cherkasy', 'Ukraine', 49.43, 32.07, 7.19),
#  ('Chernihiv', 'Ukraine', 51.5, 31.3, 5.92),
#  ('Chernivtsi', 'Ukraine', 48.31, 25.92, 7.06),
#  ('Chisinau', 'Moldova', 47.01, 28.86, 8.6),
#  ('Constanta', 'Romania', 44.2, 28.61, 11.24),
#  ('Cork', 'Ireland', 51.9, -8.5, 9.41),
#  ('Cosenza', 'Italy', 39.27, 16.29, 16.6),
#  ('Craiova', 'Romania', 44.33, 23.83, 10.51),
#  ('Daugavpils', 'Latvia', 55.88, 26.51, 5.38),
#  ('Debrecen', 'Hungary', 47.53, 21.63, 8.87),
#  ('Denizli', 'Turkey', 37.77, 29.08, 15.02),
#  ('Dijon', 'France', 47.33, 5.03, 8.69),
#  ('Dublin', 'Ireland', 53.33, -6.25, 8.49),
#  ('Dundee', 'United Kingdom', 56.47, -3.0, 6.4),
#  ('Edinburgh', 'United Kingdom', 55.95, -3.22, 7.43),
#  ('Edirne', 'Turkey', 41.67, 26.57, 10.9),
#  ('Elbasan', 'Albania', 41.12, 20.08, 15.18),
#  ('Elblag', 'Poland', 54.19, 19.4, 6.68),
#  ('Erfurt', 'Germany', 50.97, 11.03, 7.4),
#  ('Erzincan', 'Turkey', 39.75, 39.49, 8.67),
#  ('Erzurum', 'Turkey', 39.92, 41.29, 5.17),
#  ('Eskisehir', 'Turkey', 39.79, 30.53, 11.11),
#  ('Exeter', 'United Kingdom', 50.7, -3.53, 10.14),
#  ('Foggia', 'Italy', 41.46, 15.56, 13.83),
#  ('Frankfurt', 'Germany', 50.1, 8.68, 7.98),
#  ('Freiburg', 'Germany', 48.0, 7.87, 6.68),
#  ('Galway', 'Ireland', 53.27, -9.05, 10.0),
#  ('Gaziantep', 'Turkey', 37.07, 37.38, 13.46),
#  ('Geneva', 'Switzerland', 46.21, 6.14, 8.4),
#  ('Genoa', 'Italy', 44.41, 8.93, 12.94),
#  ('Glasgow', 'United Kingdom', 55.87, -4.25, 8.6),
#  ('Göteborg', 'Sweden', 57.75, 12.0, 5.76),
#  ('Granada', 'Spain', 37.16, -3.59, 16.33),
#  ('Graz', 'Austria', 47.08, 15.41, 6.91),
#  ('Grenoble', 'France', 45.18, 5.72, 8.4),
#  ('Groningen', 'Netherlands', 53.22, 6.58, 8.71),
#  ('Gyor', 'Hungary', 47.7, 17.63, 9.65),
#  ('Heidelberg', 'Germany', 49.42, 8.7, 8.47),
#  ('Helsinki', 'Finland', 60.18, 24.93, 4.19),
#  ('Horlivka', 'Ukraine', 48.3, 38.05, 7.12),
#  ('Hrodna', 'Belarus', 53.68, 23.83, 6.07),
#  ('Huelva', 'Spain', 37.25, -6.93, 17.09),
#  ('Ingolstadt', 'Germany', 48.77, 11.45, 7.57),
#  ('Innsbruck', 'Austria', 47.28, 11.41, 4.54),
#  ('Inverness', 'United Kingdom', 57.47, -4.23, 8.0),
#  ('Istanbul', 'Turkey', 41.1, 29.01, 13.2),
#  ('Kalamata', 'Greece', 37.04, 22.11, 17.3),
#  ('Karaman', 'Turkey', 37.18, 33.22, 10.41),
#  ('Karlsruhe', 'Germany', 49.0, 8.4, 8.88),
#  ('Kaunas', 'Lithuania', 54.95, 23.88, 6.05),
#  ('Kayseri', 'Turkey', 38.73, 35.49, 8.89),
#  ('Kherson', 'Ukraine', 46.63, 32.6, 8.64),
#  ('Kielce', 'Poland', 50.89, 20.66, 7.29),
#  ('Kiev', 'Ukraine', 50.43, 30.52, 6.88),
#  ('Kiruna', 'Sweden', 67.85, 20.22, -2.2),
#  ('Klaipeda', 'Lithuania', 55.72, 21.12, 7.0),
#  ('Kosice', 'Slovakia', 48.73, 21.25, 7.31),
#  ('Koszalin', 'Poland', 54.2, 16.18, 7.73),
#  ('Kremenchuk', 'Ukraine', 49.08, 33.43, 7.43),
#  ('Kryvyy Rih', 'Ukraine', 47.93, 33.34, 8.61),
#  ('Le Mans', 'France', 48.0, 0.1, 10.59),
#  ('Lille', 'France', 50.65, 3.08, 9.65),
#  ('Limoges', 'France', 45.83, 1.25, 10.32),
#  ('Linz', 'Austria', 48.32, 14.29, 6.79),
#  ('Lisbon', 'Portugal', 38.72, -9.14, 15.52),
#  ('Ljubljana', 'Slovenia', 46.06, 14.51, 9.27),
#  ('Lvov', 'Ukraine', 49.83, 24.03, 7.04),
#  ('Maastricht', 'Netherlands', 50.85, 5.68, 8.63),
#  ('Madrid', 'Spain', 40.4, -3.68, 11.19),
#  ('Magdeburg', 'Germany', 52.13, 11.62, 8.26),
#  ('Makiyivka', 'Ukraine', 48.03, 37.97, 8.7),
#  ('Malatya', 'Turkey', 38.37, 38.3, 14.13),
#  ('Malmö', 'Sweden', 55.58, 13.03, 7.33),
#  ('Manisa', 'Turkey', 38.63, 27.44, 15.1),
#  ('Marbella', 'Spain', 36.52, -4.88, 17.19),
#  ('Marseille', 'France', 43.29, 5.38, 14.98),
#  ('Mazyr', 'Belarus', 52.05, 29.27, 6.25),
#  ('Messina', 'Italy', 38.2, 15.55, 16.54),
#  ('Metz', 'France', 49.12, 6.18, 8.88),
#  ('Milan', 'Italy', 45.47, 9.21, 6.65),
#  ('Minsk', 'Belarus', 53.9, 27.57, 5.28),
#  ('Montpellier', 'France', 43.61, 3.87, 11.11),
#  ('Mulhouse', 'France', 47.75, 7.35, 6.68),
#  ('Murcia', 'Spain', 37.98, -1.13, 15.0),
#  ('Nice', 'France', 43.72, 7.27, 8.82),
#  ('Nis', 'Serbia', 43.33, 21.9, 9.36),
#  ('Novi Sad', 'Serbia', 45.25, 19.85, 10.34),
#  ('Odense', 'Denmark', 55.4, 10.38, 7.73),
#  ('Ordu', 'Turkey', 41.0, 37.87, 11.92),
#  ('Orsha', 'Belarus', 54.52, 30.42, 4.93),
#  ('Oslo', 'Norway', 59.92, 10.75, 2.32),
#  ('Ostrava', 'Czech Republic', 49.83, 18.25, 7.66),
#  ('Oulu', 'Finland', 65.0, 25.47, 1.45),
#  ('Oviedo', 'Spain', 43.35, -5.83, 10.85),
#  ('Palermo', 'Italy', 38.13, 13.35, 17.9),
#  ('Patras', 'Greece', 38.23, 21.73, 16.9),
#  ('Perpignan', 'France', 42.7, 2.9, 10.95),
#  ('Perugia', 'Italy', 43.11, 12.39, 11.7),
#  ('Pescara', 'Italy', 42.46, 14.22, 15.13),
#  ('Pinsk', 'Belarus', 52.13, 26.09, 6.42),
#  ('Pleven', 'Bulgaria', 43.42, 24.61, 10.51),
#  ('Plovdiv', 'Bulgaria', 42.15, 24.75, 8.27),
#  ('Podgorica', 'Montenegro', 42.47, 19.27, 9.99),
#  ('Poznan', 'Poland', 52.41, 16.9, 8.31),
#  ('Prague', 'Czech Republic', 50.08, 14.47, 8.05),
#  ('Reims', 'France', 49.25, 4.03, 9.4),
#  ('Riga', 'Latvia', 56.95, 24.1, 5.16),
#  ('Rijeka', 'Croatia', 45.33, 14.45, 9.27),
#  ('Rivne', 'Ukraine', 50.62, 26.25, 6.76),
#  ('Rome', 'Italy', 41.9, 12.48, 15.1),
#  ('Rostock', 'Germany', 54.07, 12.15, 8.07),
#  ('Ruse', 'Bulgaria', 43.85, 25.97, 10.59),
#  ('Salamanca', 'Spain', 40.97, -5.67, 11.63),
#  ('Salzburg', 'Austria', 47.81, 13.04, 4.62),
#  ('Samsun', 'Turkey', 41.28, 36.34, 12.05),
#  ('Santander', 'Spain', 43.38, -3.8, 13.4),
#  ('Sarajevo', 'Bosnia and Herzegovina', 43.85, 13.38, 9.6),
#  ('Sibiu', 'Romania', 45.8, 24.14, 6.97),
#  ('Siirt', 'Turkey', 37.94, 41.93, 12.48),
#  ('Sivas', 'Turkey', 39.75, 37.03, 8.05),
#  ('Skopje', 'Macedonia', 42.0, 21.43, 9.36),
#  ('Split', 'Croatia', 43.52, 16.47, 12.46),
#  ('Stara Zagora', 'Bulgaria', 42.42, 25.62, 10.9),
#  ('Stavanger', 'Norway', 58.97, 5.68, 5.53),
#  ('Stockholm', 'Sweden', 59.35, 18.1, 6.26),
#  ('Sumy', 'Ukraine', 50.92, 34.78, 6.28),
#  ('Swansea', 'United Kingdom', 51.63, -3.95, 9.73),
#  ('Szeged', 'Hungary', 46.25, 20.15, 10.34),
#  ('Tallinn', 'Estonia', 59.43, 24.73, 4.82),
#  ('Tampere', 'Finland', 61.5, 23.75, 3.59),
#  ('Tarsus', 'Turkey', 36.92, 34.88, 11.21),
#  ('Tartu', 'Estonia', 58.38, 26.71, 4.36),
#  ('Tekirdag', 'Turkey', 40.99, 27.51, 13.02),
#  ('Toulouse', 'France', 43.62, 1.45, 10.25),
#  ('Trabzon', 'Turkey', 40.98, 39.72, 10.28),
#  ('Trieste', 'Italy', 45.65, 13.8, 11.21),
#  ('Trikala', 'Greece', 39.56, 21.77, 16.0),
#  ('Trondheim', 'Norway', 63.42, 10.42, 4.53),
#  ('Turku', 'Finland', 60.45, 22.25, 4.72),
#  ('Uppsala', 'Sweden', 59.86, 17.64, 4.17),
#  ('Valencia', 'Spain', 39.49, -0.4, 16.02),
#  ('Vienna', 'Austria', 48.2, 16.37, 7.86),
#  ('Vigo', 'Spain', 42.22, -8.73, 12.85),
#  ('Vilnius', 'Lithuania', 54.68, 25.32, 5.38),
#  ('Warsaw', 'Poland', 52.25, 21.0, 7.2),
#  ('Wroclaw', 'Poland', 51.11, 17.03, 7.17),
#  ('Yevpatoriya', 'Ukraine', 45.2, 33.36, 10.02),
#  ('Zaragoza', 'Spain', 41.65, -0.89, 14.17),
#  ('Zhytomyr', 'Ukraine', 50.25, 28.66, 6.67),
#  ('Zonguldak', 'Turkey', 41.43, 31.78, 10.64),
#  ('Zurich', 'Switzerland', 47.38, 8.56, 6.68)]

# %% [markdown]
# ## 1.2 Subqueries using the SELECT statement

# %% [markdown]
# A subquery is a query within another query. The outer query is called as main query and inner query is called as subquery. The subquery must be enclosed with parenthesis and generally executes first, and its output is used to complete the query condition for the main or outer query. We will go through examples of how subqueries can be used to answers different types of questions then later, we will use our learnings to work on the challenges.

# %%
# Example 1
# Subqueries can occur in the select list of the containing query
# as shown below;
# Let's find all countries in the Countries table with no city in the Cities table
# 
# %%sql
SELECT country
FROM world_countries
WHERE NOT EXISTS (SELECT * FROM world_cities
                  WHERE world_cities.country = world_countries.country)
# Out:
#  * sqlite://
# Done.
# [('Cyprus',), ('Iceland',), ('Kosovo',), ('Liechtenstein',), ('Luxembourg',)]

# %%
# Example 2
# Find the European countries with cities experiencing temperature > 20?
# 
# %%sql
SELECT country
FROM world_countries
WHERE EU = 'yes'
AND EXISTS (SELECT * FROM world_cities
            WHERE world_cities.country = world_countries.country
            AND temperature > 15)
# Out:
#  * sqlite://
# Done.
# [('Greece',), ('Italy',), ('Portugal',), ('Spain',)]

# %%
# Example 3: Method 1
# Find the westernmost city, returning the city and longitude
# 
# %%sql
SELECT city, longitude
FROM world_cities C1
WHERE NOT EXISTS (SELECT * FROM world_cities C2
                  WHERE C2.longitude < C1.longitude)
# Out:
#  * sqlite://
# Done.
# [('Lisbon', -9.14)]

# %%
# Example 3: Method 2
# Find the westernmost city, returning the city and longitude
# 
# %%sql
SELECT city, longitude
FROM world_cities
WHERE longitude = (SELECT min(longitude) FROM world_cities)
# Out:
#  * sqlite://
# Done.
# [('Lisbon', -9.14)]

# %%
# Example 4:
# How many cities are in the EU?
# 
# %%sql
SELECT count()
FROM world_cities
WHERE country IN (SELECT country FROM world_countries WHERE EU = 'yes')
# Out:
#  * sqlite://
# Done.
# [(150,)]

# %% [markdown]
# ### <font color="green">1.2 Challenges</font>

# %%
# Challenge 1
# Find number of countries that have a city with latitude > 1000 (start with country list)
# 
# %%sql
SELECT COUNT("country")
FROM world_countries
WHERE country IN(SELECT country FROM world_cities  WHERE latitude > 1000)

## NO COUNTRIES WITH LATITUDE >1000.
# Out:
#  * sqlite://
# (sqlite3.OperationalError) unrecognized token: "#"
# [SQL: SELECT COUNT("country")
# FROM world_countries
# WHERE country IN(SELECT country FROM world_cities  WHERE latitude > 1000)
#
# ## NO COUNTRIES WITH LATITUDE >1000.]
# (Background on this error at: http://sqlalche.me/e/14/e3q8)

# %%
# Challenge 2
# Find three western most cities returning both the cities and their longitude
#
# %%sql
SELECT city , longitude
FROM world_cities 
WHERE latitude IN (SELECT latitude FROM world_cities WHERE "latitude" > 2)  ORDER BY  latitude  ASC limit 3
# Out:
#  * sqlite://
# Done.
# [('Algeciras', -5.47), ('Marbella', -4.88), ('Antalya', 30.7)]

# %%
# Challenge 3
# Find cities with temperature is more than 50% higher than the average; 
# We will return the city, country, and temperature, ordered by descending temperature
# Hint: avg(temperature) * 1.5
# 
# %%sql
SELECT country, city, temperature
FROM world_cities
WHERE(SELECT AVG("temperature")*1.5 FROM world_cities) ORDER BY temperature  DESC
# Out:
#  * sqlite://
# Done.
# [('Turkey', 'Adana', 18.67),
#  ('Italy', 'Palermo', 17.9),
#  ('Greece', 'Athens', 17.41),
#  ('Spain', 'Algeciras', 17.38),
#  ('Spain', 'Cartagena', 17.32),
#  ('Greece', 'Kalamata', 17.3),
#  ('Spain', 'Marbella', 17.19),
#  ('Spain', 'Huelva', 17.09),
#  ('Greece', 'Patras', 16.9),
#  ('Italy', 'Cosenza', 16.6),
#  ('Italy', 'Messina', 16.54),
#  ('Spain', 'Granada', 16.33),
#  ('Spain', 'Valencia', 16.02),
#  ('Greece', 'Trikala', 16.0),
#  ('Spain', 'Barcelona', 15.78),
#  ('Spain', 'Badajoz', 15.61),
#  ('Portugal', 'Lisbon', 15.52),
#  ('Albania', 'Elbasan', 15.18),
#  ('Italy', 'Bari', 15.15),
#  ('Italy', 'Pescara', 15.13),
#  ('Turkey', 'Manisa', 15.1),
#  ('Italy', 'Rome', 15.1),
#  ('Italy', 'Catania', 15.04),
#  ('Turkey', 'Denizli', 15.02),
#  ('Spain', 'Murcia', 15.0),
#  ('France', 'Marseille', 14.98),
#  ('Spain', 'Zaragoza', 14.17),
#  ('Turkey', 'Batman', 14.16),
#  ('Turkey', 'Malatya', 14.13),
#  ('Italy', 'Foggia', 13.83),
#  ('Italy', 'Ancona', 13.52),
#  ('Turkey', 'Gaziantep', 13.46),
#  ('Portugal', 'Braga', 13.42),
#  ('Spain', 'Santander', 13.4),
#  ('Turkey', 'Istanbul', 13.2),
#  ('Turkey', 'Tekirdag', 13.02),
#  ('Italy', 'Genoa', 12.94),
#  ('Spain', 'Vigo', 12.85),
#  ('Spain', 'Albacete', 12.62),
#  ('Turkey', 'Siirt', 12.48),
#  ('Croatia', 'Split', 12.46),
#  ('Turkey', 'Samsun', 12.05),
#  ('Bulgaria', 'Burgas', 11.93),
#  ('Turkey', 'Ordu', 11.92),
#  ('Turkey', 'Antalya', 11.88),
#  ('France', 'Bordeaux', 11.87),
#  ('Italy', 'Perugia', 11.7),
#  ('Italy', 'Bologna', 11.69),
#  ('Spain', 'Salamanca', 11.63),
#  ('Spain', 'Bilbao', 11.41),
#  ('Romania', 'Constanta', 11.24),
#  ('Turkey', 'Tarsus', 11.21),
#  ('Italy', 'Trieste', 11.21),
#  ('Spain', 'Madrid', 11.19),
#  ('Turkey', 'Bursa', 11.16),
#  ('Turkey', 'Eskisehir', 11.11),
#  ('France', 'Montpellier', 11.11),
#  ('France', 'Brest', 11.02),
#  ('France', 'Angers', 10.98),
#  ('France', 'Perpignan', 10.95),
#  ('Turkey', 'Edirne', 10.9),
#  ('Bulgaria', 'Stara Zagora', 10.9),
#  ('Spain', 'Oviedo', 10.85),
#  ('Turkey', 'Zonguldak', 10.64),
#  ('Romania', 'Bucharest', 10.59),
#  ('France', 'Le Mans', 10.59),
#  ('Bulgaria', 'Ruse', 10.59),
#  ('Romania', 'Craiova', 10.51),
#  ('Bulgaria', 'Pleven', 10.51),
#  ('Spain', 'Burgos', 10.45),
#  ('Turkey', 'Karaman', 10.41),
#  ('Serbia', 'Novi Sad', 10.34),
#  ('Hungary', 'Szeged', 10.34),
#  ('France', 'Limoges', 10.32),
#  ('Turkey', 'Trabzon', 10.28),
#  ('France', 'Toulouse', 10.25),
#  ('France', 'Amiens', 10.17),
#  ('United Kingdom', 'Exeter', 10.14),
#  ('Ukraine', 'Yevpatoriya', 10.02),
#  ('Ireland', 'Galway', 10.0),
#  ('Montenegro', 'Podgorica', 9.99),
#  ('United Kingdom', 'Bournemouth', 9.97),
#  ('France', 'Caen', 9.96),
#  ('Turkey', 'Ankara', 9.86),
#  ('Serbia', 'Belgrade', 9.85),
#  ('Romania', 'Braila', 9.78),
#  ('United Kingdom', 'Swansea', 9.73),
#  ('Slovakia', 'Bratislava', 9.65),
#  ('Belgium', 'Brugge', 9.65),
#  ('Hungary', 'Gyor', 9.65),
#  ('France', 'Lille', 9.65),
#  ('Andorra', 'Andorra', 9.6),
#  ('Bosnia and Herzegovina', 'Sarajevo', 9.6),
#  ('Hungary', 'Budapest', 9.55),
#  ('Ireland', 'Cork', 9.41),
#  ('France', 'Reims', 9.4),
#  ('Serbia', 'Nis', 9.36),
#  ('Macedonia', 'Skopje', 9.36),
#  ('Romania', 'Arad', 9.32),
#  ('Slovenia', 'Ljubljana', 9.27),
#  ('Croatia', 'Rijeka', 9.27),
#  ('United Kingdom', 'Cambridge', 9.25),
#  ('United Kingdom', 'Blackpool', 9.15),
#  ('Italy', 'Bergamo', 9.12),
#  ('Netherlands', 'Amsterdam', 8.93),
#  ('Turkey', 'Kayseri', 8.89),
#  ('Germany', 'Karlsruhe', 8.88),
#  ('France', 'Metz', 8.88),
#  ('Romania', 'Baia Mare', 8.87),
#  ('Hungary', 'Debrecen', 8.87),
#  ('France', 'Nice', 8.82),
#  ('United Kingdom', 'Birmingham', 8.81),
#  ('Germany', 'Bielefeld', 8.78),
#  ('Germany', 'Berlin', 8.72),
#  ('Netherlands', 'Groningen', 8.71),
#  ('Ukraine', 'Makiyivka', 8.7),
#  ('France', 'Dijon', 8.69),
#  ('Turkey', 'Erzincan', 8.67),
#  ('Ukraine', 'Kherson', 8.64),
#  ('Germany', 'Bonn', 8.63),
#  ('Netherlands', 'Maastricht', 8.63),
#  ('Ukraine', 'Kryvyy Rih', 8.61),
#  ('Moldova', 'Chisinau', 8.6),
#  ('United Kingdom', 'Glasgow', 8.6),
#  ('Ireland', 'Dublin', 8.49),
#  ('United Kingdom', 'Belfast', 8.48),
#  ('Germany', 'Heidelberg', 8.47),
#  ('Switzerland', 'Geneva', 8.4),
#  ('France', 'Grenoble', 8.4),
#  ('United Kingdom', 'Bradford', 8.39),
#  ('Poland', 'Poznan', 8.31),
#  ('Bulgaria', 'Plovdiv', 8.27),
#  ('Germany', 'Magdeburg', 8.26),
#  ('Moldova', 'Balti', 8.23),
#  ('Romania', 'Botosani', 8.23),
#  ('Germany', 'Bremen', 8.14),
#  ('United Kingdom', 'Aberdeen', 8.1),
#  ('Germany', 'Rostock', 8.07),
#  ('Germany', 'Chemnitz', 8.05),
#  ('Czech Republic', 'Prague', 8.05),
#  ('Turkey', 'Sivas', 8.05),
#  ('United Kingdom', 'Inverness', 8.0),
#  ('Germany', 'Frankfurt', 7.98),
#  ('Czech Republic', 'Brno', 7.86),
#  ('Austria', 'Vienna', 7.86),
#  ('Poland', 'Koszalin', 7.73),
#  ('Denmark', 'Odense', 7.73),
#  ('Poland', 'Bytom', 7.66),
#  ('Czech Republic', 'Ostrava', 7.66),
#  ('Germany', 'Ingolstadt', 7.57),
#  ('Denmark', 'Aalborg', 7.52),
#  ('Romania', 'Bacau', 7.51),
#  ('United Kingdom', 'Edinburgh', 7.43),
#  ('Ukraine', 'Kremenchuk', 7.43),
#  ('Germany', 'Erfurt', 7.4),
#  ('Sweden', 'Malmö', 7.33),
#  ('Slovakia', 'Kosice', 7.31),
#  ('Poland', 'Kielce', 7.29),
#  ('Poland', 'Warsaw', 7.2),
#  ('Ukraine', 'Cherkasy', 7.19),
#  ('Poland', 'Wroclaw', 7.17),
#  ('Poland', 'Bydgoszcz', 7.14),
#  ('Ukraine', 'Horlivka', 7.12),
#  ('Ukraine', 'Chernivtsi', 7.06),
#  ('Ukraine', 'Lvov', 7.04),
#  ('Lithuania', 'Klaipeda', 7.0),
#  ('Ukraine', 'Bila Tserkva', 6.98),
#  ('Romania', 'Sibiu', 6.97),
#  ('Austria', 'Graz', 6.91),
#  ('Ukraine', 'Kiev', 6.88),
#  ('Austria', 'Linz', 6.79),
#  ('Ukraine', 'Rivne', 6.76),
#  ('Belarus', 'Brest', 6.73),
#  ('Switzerland', 'Basel', 6.68),
#  ('Poland', 'Elblag', 6.68),
#  ('Germany', 'Freiburg', 6.68),
#  ('France', 'Mulhouse', 6.68),
#  ('Switzerland', 'Zurich', 6.68),
#  ('Ukraine', 'Zhytomyr', 6.67),
#  ('Italy', 'Milan', 6.65),
#  ('Belarus', 'Pinsk', 6.42),
#  ('United Kingdom', 'Dundee', 6.4),
#  ('Ukraine', 'Sumy', 6.28),
#  ('Sweden', 'Stockholm', 6.26),
#  ('Belarus', 'Mazyr', 6.25),
#  ('Poland', 'Bialystok', 6.07),
#  ('Belarus', 'Hrodna', 6.07),
#  ('Lithuania', 'Kaunas', 6.05),
#  ('Ukraine', 'Chernihiv', 5.92),
#  ('Sweden', 'Göteborg', 5.76),
#  ('Norway', 'Stavanger', 5.53),
#  ('Latvia', 'Daugavpils', 5.38),
#  ('Lithuania', 'Vilnius', 5.38),
#  ('Belarus', 'Minsk', 5.28),
#  ('Turkey', 'Erzurum', 5.17),
#  ('Latvia', 'Riga', 5.16),
#  ('Belarus', 'Orsha', 4.93),
#  ('Estonia', 'Tallinn', 4.82),
#  ('Finland', 'Turku', 4.72),
#  ('Austria', 'Salzburg', 4.62),
#  ('Germany', 'Augsburg', 4.54),
#  ('Austria', 'Innsbruck', 4.54),
#  ('Norway', 'Trondheim', 4.53),
#  ('Norway', 'Bodo', 4.5),
#  ('Estonia', 'Tartu', 4.36),
#  ('Finland', 'Helsinki', 4.19),
#  ('Sweden', 'Uppsala', 4.17),
#  ('Finland', 'Tampere', 3.59),
#  ('Norway', 'Oslo', 2.32),
#  ('Norway', 'Bergen', 1.75),
#  ('Finland', 'Oulu', 1.45),
#  ('Sweden', 'Abisko', 0.2),
#  ('Sweden', 'Kiruna', -2.2)]

# %%
# Challenge 4
# How many cities are not in the EU and without a coastline?
# Hint: "not in"
# 
# %%sql
SELECT COUNT("city")
FROM world_cities
WHERE country in(SELECT country FROM world_countries WHERE EU = 'no' and coastline ='no')
# Out:
#  * sqlite://
# Done.
# [(16,)]

# %%
# Challenge 5
# Find the number of countries with no coastline and a city with longitude < 10
# 
# %%sql
SELECT COUNT("country")
FROM world_countries
WHERE coastline = 'no'
AND EXISTS(SELECT city FROM world_cities WHERE longitude <10 );
# Out:
#  * sqlite://
# Done.
# [(13,)]

# %%
# Challenge 6
# Find countries in Countries table with no city in Cities table
# 
# %%sql
SELECT country
FROM world_countries
WHERE NOT EXISTS (SELECT * FROM world_cities
                  WHERE world_cities.country = world_countries.country)
# Out:
#  * sqlite://
# Done.
# [('Cyprus',), ('Iceland',), ('Kosovo',), ('Liechtenstein',), ('Luxembourg',)]

# %%
# Challenge 7
# Find all cities in a country whose population is < 2, returning the city and country.
# 
# %%sql
SELECT city
FROM world_cities
WHERE EXISTS (SELECT * FROM world_countries WHERE  population < 2)
# Out:
#  * sqlite://
# Done.
# [('Aalborg',),
#  ('Aberdeen',),
#  ('Abisko',),
#  ('Adana',),
#  ('Albacete',),
#  ('Algeciras',),
#  ('Amiens',),
#  ('Amsterdam',),
#  ('Ancona',),
#  ('Andorra',),
#  ('Angers',),
#  ('Ankara',),
#  ('Antalya',),
#  ('Arad',),
#  ('Athens',),
#  ('Augsburg',),
#  ('Bacau',),
#  ('Badajoz',),
#  ('Baia Mare',),
#  ('Balti',),
#  ('Barcelona',),
#  ('Bari',),
#  ('Basel',),
#  ('Batman',),
#  ('Belfast',),
#  ('Belgrade',),
#  ('Bergamo',),
#  ('Bergen',),
#  ('Berlin',),
#  ('Bialystok',),
#  ('Bielefeld',),
#  ('Bila Tserkva',),
#  ('Bilbao',),
#  ('Birmingham',),
#  ('Blackpool',),
#  ('Bodo',),
#  ('Bologna',),
#  ('Bonn',),
#  ('Bordeaux',),
#  ('Botosani',),
#  ('Bournemouth',),
#  ('Bradford',),
#  ('Braga',),
#  ('Braila',),
#  ('Bratislava',),
#  ('Bremen',),
#  ('Brest',),
#  ('Brest',),
#  ('Brno',),
#  ('Brugge',),
#  ('Bucharest',),
#  ('Budapest',),
#  ('Burgas',),
#  ('Burgos',),
#  ('Bursa',),
#  ('Bydgoszcz',),
#  ('Bytom',),
#  ('Caen',),
#  ('Cambridge',),
#  ('Cartagena',),
#  ('Catania',),
#  ('Chemnitz',),
#  ('Cherkasy',),
#  ('Chernihiv',),
#  ('Chernivtsi',),
#  ('Chisinau',),
#  ('Constanta',),
#  ('Cork',),
#  ('Cosenza',),
#  ('Craiova',),
#  ('Daugavpils',),
#  ('Debrecen',),
#  ('Denizli',),
#  ('Dijon',),
#  ('Dublin',),
#  ('Dundee',),
#  ('Edinburgh',),
#  ('Edirne',),
#  ('Elbasan',),
#  ('Elblag',),
#  ('Erfurt',),
#  ('Erzincan',),
#  ('Erzurum',),
#  ('Eskisehir',),
#  ('Exeter',),
#  ('Foggia',),
#  ('Frankfurt',),
#  ('Freiburg',),
#  ('Galway',),
#  ('Gaziantep',),
#  ('Geneva',),
#  ('Genoa',),
#  ('Glasgow',),
#  ('Granada',),
#  ('Graz',),
#  ('Grenoble',),
#  ('Groningen',),
#  ('Gyor',),
#  ('Göteborg',),
#  ('Heidelberg',),
#  ('Helsinki',),
#  ('Horlivka',),
#  ('Hrodna',),
#  ('Huelva',),
#  ('Ingolstadt',),
#  ('Innsbruck',),
#  ('Inverness',),
#  ('Istanbul',),
#  ('Kalamata',),
#  ('Karaman',),
#  ('Karlsruhe',),
#  ('Kaunas',),
#  ('Kayseri',),
#  ('Kherson',),
#  ('Kielce',),
#  ('Kiev',),
#  ('Kiruna',),
#  ('Klaipeda',),
#  ('Kosice',),
#  ('Koszalin',),
#  ('Kremenchuk',),
#  ('Kryvyy Rih',),
#  ('Le Mans',),
#  ('Lille',),
#  ('Limoges',),
#  ('Linz',),
#  ('Lisbon',),
#  ('Ljubljana',),
#  ('Lvov',),
#  ('Maastricht',),
#  ('Madrid',),
#  ('Magdeburg',),
#  ('Makiyivka',),
#  ('Malatya',),
#  ('Malmö',),
#  ('Manisa',),
#  ('Marbella',),
#  ('Marseille',),
#  ('Mazyr',),
#  ('Messina',),
#  ('Metz',),
#  ('Milan',),
#  ('Minsk',),
#  ('Montpellier',),
#  ('Mulhouse',),
#  ('Murcia',),
#  ('Nice',),
#  ('Nis',),
#  ('Novi Sad',),
#  ('Odense',),
#  ('Ordu',),
#  ('Orsha',),
#  ('Oslo',),
#  ('Ostrava',),
#  ('Oulu',),
#  ('Oviedo',),
#  ('Palermo',),
#  ('Patras',),
#  ('Perpignan',),
#  ('Perugia',),
#  ('Pescara',),
#  ('Pinsk',),
#  ('Pleven',),
#  ('Plovdiv',),
#  ('Podgorica',),
#  ('Poznan',),
#  ('Prague',),
#  ('Reims',),
#  ('Riga',),
#  ('Rijeka',),
#  ('Rivne',),
#  ('Rome',),
#  ('Rostock',),
#  ('Ruse',),
#  ('Salamanca',),
#  ('Salzburg',),
#  ('Samsun',),
#  ('Santander',),
#  ('Sarajevo',),
#  ('Sibiu',),
#  ('Siirt',),
#  ('Sivas',),
#  ('Skopje',),
#  ('Split',),
#  ('Stara Zagora',),
#  ('Stavanger',),
#  ('Stockholm',),
#  ('Sumy',),
#  ('Swansea',),
#  ('Szeged',),
#  ('Tallinn',),
#  ('Tampere',),
#  ('Tarsus',),
#  ('Tartu',),
#  ('Tekirdag',),
#  ('Toulouse',),
#  ('Trabzon',),
#  ('Trieste',),
#  ('Trikala',),
#  ('Trondheim',),
#  ('Turku',),
#  ('Uppsala',),
#  ('Valencia',),
#  ('Vienna',),
#  ('Vigo',),
#  ('Vilnius',),
#  ('Warsaw',),
#  ('Wroclaw',),
#  ('Yevpatoriya',),
#  ('Zaragoza',),
#  ('Zhytomyr',),
#  ('Zonguldak',),
#  ('Zurich',)]

# %%
# Challenge 8
# Find all countries with no city having a temperature > 6
# 
# %%sql
SELECT country
FROM world_countries
WHERE NOT EXISTS (SELECT * FROM world_cities 
                 WHERE world_cities.country = world_countries.country
                 and temperature > 6)
# Out:
#  * sqlite://
# Done.
# [('Cyprus',),
#  ('Estonia',),
#  ('Finland',),
#  ('Iceland',),
#  ('Kosovo',),
#  ('Latvia',),
#  ('Liechtenstein',),
#  ('Luxembourg',),
#  ('Norway',)]
